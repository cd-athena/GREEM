# %%
from os import system
import matplotlib.pyplot as plt
import seaborn as sns
from monitoring import HardwareTracker
# Out:
# Your installed package `nvidia-ml-py` is corrupted. Skip patch functions `nvmlDeviceGet{Compute,Graphics,MPSCompute}RunningProcesses`. You may get incorrect or incomplete results. Please consider reinstall package `nvidia-ml-py` via `pip3 install --force-reinstall nvidia-ml-py nvitop`.
# Your installed package `nvidia-ml-py` is corrupted. Skip patch functions `nvmlDeviceGetMemoryInfo`. You may get incorrect or incomplete results. Please consider reinstall package `nvidia-ml-py` via `pip3 install --force-reinstall nvidia-ml-py nvitop`.

# %%
tracker = HardwareTracker(measure_power_secs=0.5, cuda_enabled=True)
# Out:
# [codecarbon INFO @ 15:48:31] offline tracker init

# %%
tracker.start()

# %%
tracker.monitor_process('ffmpeg -hide_banner -loglevel error -y -i Basketball_s000.265 -c:v libx264 -c:a copy test.mp4', 'avc')

# %%
tracker.monitor_process('sleep 1')

# %%
tracker.monitor_process('ffmpeg -hide_banner -loglevel error -y -i Basketball_s000.265 -c:v libx265 -c:a copy test.mp4', 'hevc')
tracker.stop()
# Out:
# x265 [info]: HEVC encoder version 3.4
# x265 [info]: build info [Linux][GCC 7.5.0][64 bit] 8bit+10bit+12bit
# x265 [info]: using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# x265 [info]: Main profile, Level-5 (Main tier)
# x265 [info]: Thread pool 0 using 64 threads on numa nodes 0,1
# x265 [info]: Slices                              : 1
# x265 [info]: frame threads / pool features       : 6 / wpp(34 rows)
# x265 [info]: Coding QT: max CU size, min CU size : 64 / 8
# x265 [info]: Residual QT: max TU size, max depth : 32 / 1 inter / 1 intra
# x265 [info]: ME / range / subpel / merge         : hex / 57 / 2 / 3
# x265 [info]: Keyframe min / max / scenecut / bias  : 23 / 250 / 40 / 5.00
# x265 [info]: Lookahead / bframes / badapt        : 20 / 4 / 2
# x265 [info]: b-pyramid / weightp / weightb       : 1 / 1 / 0
# x265 [info]: References / ref-limit  cu / depth  : 3 / off / on
# x265 [info]: AQ: mode / str / qg-size / cu-tree  : 2 / 1.0 / 32 / 1
# ...

# %%
# df = tracker.to_dataframe()
# df

# %%
len(tracker.collected_codecarbon_data)
# Out:
# 49

# %%
print(len(tracker.collected_nvitop_data), len(tracker.collected_codecarbon_data))
# Out:
# 49 49

# %%
# tracker.collected_codecarbon_data

# %%
# tracker.collected_nvitop_data

# %%
for carbon, nvi in zip(tracker.collected_codecarbon_data, tracker.collected_nvitop_data):
    carbon_dict = carbon.values
    # print(len(carbon_dict))
    nvi_dict = nvi.values
    carbon_dict.update(nvi_dict)
    print(len(carbon_dict))
# Out:
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 33
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133
# 133

# %%
tracker.to_dataframe()
# Out:
#               timestamp project_name                                run_id  \
# 0   2024-05-15T15:48:33          avc  e22e6e78-93dc-416f-94f4-ebd536a011b7
# 1   2024-05-15T15:48:34          avc  e22e6e78-93dc-416f-94f4-ebd536a011b7
# 2   2024-05-15T15:48:34          avc  e22e6e78-93dc-416f-94f4-ebd536a011b7
# 3   2024-05-15T15:48:35          avc  e22e6e78-93dc-416f-94f4-ebd536a011b7
# 4   2024-05-15T15:48:35          avc  e22e6e78-93dc-416f-94f4-ebd536a011b7
# 5   2024-05-15T15:48:36          avc  e22e6e78-93dc-416f-94f4-ebd536a011b7
# 6   2024-05-15T15:48:36          avc  e22e6e78-93dc-416f-94f4-ebd536a011b7
# 7   2024-05-15T15:48:37          avc  e22e6e78-93dc-416f-94f4-ebd536a011b7
# 8   2024-05-15T15:48:37          avc  e22e6e78-93dc-416f-94f4-ebd536a011b7
# 9   2024-05-15T15:48:38          avc  e22e6e78-93dc-416f-94f4-ebd536a011b7
# 10  2024-05-15T15:48:38          avc  e22e6e78-93dc-416f-94f4-ebd536a011b7
# ...

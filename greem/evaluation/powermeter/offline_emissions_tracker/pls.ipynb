# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
first_measurement_df = pd.read_csv('Data_20220511_103850.csv')
second_measurement_df = pd.read_csv('Data_20220511_104432.csv')
# period_df = pd.read_csv('period_monitoring_results.csv', index_col=0)

# %%
ax = first_measurement_df['Reading'].plot.line()
ax.set_xlabel('Powermeter Measurement Datapoints (5ms)')
ax.set_ylabel('Energy Consumption')
# Out:
# Text(0, 0.5, 'Energy Consumption')

# %%
ax = second_measurement_df['Reading'].plot.line()
ax.set_xlabel('Powermeter Measurement Datapoints (5ms)')
ax.set_ylabel('Energy Consumption')
# Out:
# Text(0, 0.5, 'Energy Consumption')

# %%
# first_peak = first_measurement_df['Reading'].idxmax()
# second_peak = first_measurement_df['Reading'][6000:].idxmax()
# first_df = test_df['Reading'][first_peak - 200:5800]
# first_df = first_df.reset_index()
# second_df = first_measurement_df['Reading'][second_peak - 400:6800]
# second_df = second_df.reset_index()

first_peak = first_measurement_df['Reading'].idxmax()
second_peak = first_measurement_df['Reading'][6000:].idxmax()

first_measurement_first_peak = first_measurement_df['Reading'][first_peak - 400:]
first_measurement_first_peak = first_measurement_first_peak.reset_index()
first_measurement_second_peak = first_measurement_df['Reading'][second_peak - 400:]
first_measurement_second_peak = first_measurement_second_peak.reset_index()


ax = first_measurement_first_peak['Reading'][:3500].plot.line()
first_measurement_second_peak['Reading'][:3500].plot.line()
ax.set_xlabel('Powermeter Measurement Datapoints (5ms)')
ax.set_ylabel('Energy Consumption')
# Out:
# Text(0, 0.5, 'Energy Consumption')

# %%
first_peak = second_measurement_df['Reading'].idxmax()
second_peak = second_measurement_df['Reading'][6000:].idxmax()

second_measurement_first_peak = second_measurement_df['Reading'][first_peak - 200:5800]
second_measurement_first_peak = second_measurement_first_peak.reset_index()
second_measurement_second_peak = second_measurement_df['Reading'][second_peak - 250:]
second_measurement_second_peak = second_measurement_second_peak.reset_index()


ax = second_measurement_first_peak['Reading'][:3400].plot.line()
second_measurement_second_peak['Reading'][:3400].plot.line()

ax.set_xlabel('Powermeter Measurement Datapoints (5ms)')
ax.set_ylabel('Energy Consumption')
# Out:
# Text(0, 0.5, 'Energy Consumption')

# %%
ax = first_measurement_first_peak['Reading'][:3500].plot.line()
first_measurement_second_peak['Reading'][:3500].plot.line()
second_measurement_first_peak['Reading'][:3500].plot.line()
second_measurement_second_peak['Reading'][:3500].plot.line()

ax.set_xlabel('Powermeter Measurement Datapoints (5ms)')
ax.set_ylabel('Energy Consumption')
# Out:
# Text(0, 0.5, 'Energy Consumption')

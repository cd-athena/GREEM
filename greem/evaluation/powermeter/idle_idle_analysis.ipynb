# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as p

# %%
# df_without_cc = pd.read_csv('idle_idle_powermeter_wo_cc.csv')
df_without_cc = pd.concat(
    [pd.read_csv(f'idle_idle_powermeter_wo_cc_{i}.csv') for i in range(1, 4)], axis=1
)

df_without_cc['Reading'].plot.line()

# df_with_cc = pd.read_csv('idle_idle_powermeter_with_cc.csv')
# Out:
# <Axes: >

# %%
df_with_cc = pd.concat(
    [pd.read_csv(f'idle_idle_powermeter_with_cc_{i}.csv') for i in range(1, 4)], axis=1
)

df_with_cc['Reading'].plot.line()
# Out:
# <Axes: >

# %%
sns.lineplot(df_with_cc, x=df_with_cc.index, y='Reading')
sns.lineplot(df_without_cc, x=df_without_cc.index, y='Reading')
# Out:
# <Axes: ylabel='Reading'>

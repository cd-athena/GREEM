# %%
from pynvml import smi

# %%
nvsmi = smi.nvidia_smi.getInstance()
  
results = nvsmi.DeviceQuery()
# Out:
# [{'id': '00000000:01:00.0', 'product_name': 'NVIDIA GeForce GTX 1080 Ti', 'product_brand': 'GeForce', 'display_mode': 'Disabled', 'display_active': 'Disabled', 'persistence_mode': 'Disabled', 'mig_mode': {'current_mm': 'Disabled', 'pending_mm': 'Disabled'}, 'accounting_mode': 'Disabled', 'accounting_mode_buffer_size': '4000', 'driver_model': {'current_dm': 'N/A', 'pending_dm': 'N/A'}, 'serial': 'N/A', 'uuid': 'GPU-a2512dc7-f7c2-ebb4-9001-2588ed530c8f', 'minor_number': '0', 'vbios_version': '86.02.39.00.A2', 'multigpu_board': 'No', 'board_id': '0x100', 'inforom_version': {'img_version': 'G001.0000.01.04', 'oem_object': '1.1', 'ecc_object': 'N/A', 'pwr_object': 'N/A'}, 'gpu_operation_mode': {'current_gom': 'N/A', 'pending_gom': 'N/A'}, 'pci': {'pci_bus': '01', 'pci_device': '00', 'pci_domain': '0000', 'pci_device_id': '1B0610DE', 'pci_bus_id': '00000000:01:00.0', 'pci_sub_system_id': '1211196E', 'pci_gpu_link_info': {'pcie_gen': {'max_link_gen': '3', 'current_link_gen': '1'}, 'link_widths': {'max_link_width': '16x', 'current_link_width': '16x'}}, 'pci_bridge_chip': {'bridge_chip_type': 'N/A', 'bridge_chip_fw': 'N/A'}, 'replay_counter': '0', 'tx_util': 0, 'tx_util_unit': 'KB/s', 'rx_util': 0, 'rx_util_unit': 'KB/s'}, 'fan_speed': 41, 'fan_speed_unit': '%', 'performance_state': 'P8', 'clocks_throttle': {'clocks_throttle_reason_gpu_idle': 'Active', 'clocks_throttle_reason_applications_clocks_setting': 'Not Active', 'clocks_throttle_reason_sw_power_cap': 'Not Active', 'clocks_throttle_reason_hw_slowdown': 'Not Active', 'clocks_throttle_reason_none': 'N/A'}, 'fb_memory_usage': {'total': 11175.375, 'used': 514.875, 'free': 10660.5, 'unit': 'MiB'}, 'bar1_memory_usage': {'total': 256.0, 'used': 6.3125, 'free': 249.6875, 'unit': 'MiB'}, 'compute_mode': 'Default', 'utilization': {'gpu_util': 0, 'memory_util': 0, 'encoder_util': 0, 'decoder_util': 0, 'unit': '%'}, 'ecc_mode': {'current_ecc': 'N/A', 'pending_ecc': 'N/A'}, 'ecc_errors': {'volatile': {'single_bit': {'device_memory': 'N/A', 'dram': 'N/A', 'register_file': 'N/A', 'l1_cache': 'N/A', 'l2_cache': 'N/A', 'texture_memory': 'N/A', 'cbu': 'N/A', 'sram': 'N/A', 'total': 'N/A'}, 'double_bit': {'device_memory': 'N/A', 'dram': 'N/A', 'register_file': 'N/A', 'l1_cache': 'N/A', 'l2_cache': 'N/A', 'texture_memory': 'N/A', 'cbu': 'N/A', 'sram': 'N/A', 'total': 'N/A'}}, 'aggregate': {'single_bit': {'device_memory': 'N/A', 'dram': 'N/A', 'register_file': 'N/A', 'l1_cache': 'N/A', 'l2_cache': 'N/A', 'texture_memory': 'N/A', 'cbu': 'N/A', 'sram': 'N/A', 'total': 'N/A'}, 'double_bit': {'device_memory': 'N/A', 'dram': 'N/A', 'register_file': 'N/A', 'l1_cache': 'N/A', 'l2_cache': 'N/A', 'texture_memory': 'N/A', 'cbu': 'N/A', 'sram': 'N/A', 'total': 'N/A'}}}, 'retired_pages': {'multiple_single_bit_retirement': None, 'double_bit_retirement': None, 'pending_retirement': 'N/A'}, 'temperature': {'gpu_temp': 26, 'gpu_temp_max_threshold': 96, 'gpu_temp_slow_threshold': 93, 'unit': 'C'}, 'power_readings': {'power_management': 'Supported', 'power_draw': 9.473, 'power_limit': 250.0, 'default_power_limit': 250.0, 'enforced_power_limit': 250.0, 'min_power_limit': 125.0, 'max_power_limit': 300.0, 'power_state': 'P8', 'unit': 'W'}, 'clocks': {'graphics_clock': 139, 'sm_clock': 139, 'mem_clock': 405, 'unit': 'MHz'}, 'applications_clocks': {'graphics_clock': 'N/A', 'mem_clock': 'N/A', 'unit': 'MHz'}, 'default_applications_clocks': {'graphics_clock': 'N/A', 'mem_clock': 'N/A', 'unit': 'MHz'}, 'max_clocks': {'graphics_clock': 1961, 'sm_clock': 1961, 'mem_clock': 5505, 'unit': 'MHz'}, 'clock_policy': {'auto_boost': 'N/A', 'auto_boost_default': 'N/A'}, 'supported_clocks': [{'current': 5505, 'unit': 'MHz', 'supported_graphics_clock': [1961, 1949, 1936, 1923, 1911, 1898, 1885, 1873, 1860, 1847, 1835, 1822, 1809, 1797, 1784, 1771, 1759, 1746, 1733, 1721, 1708, 1695, 1683, 1670, 1657, 1645, 1632, 1620, 1607, 1594, 1582, 1569, 1556, 1544, 1531, 1518, 1506, 1493, 1480, 1468, 1455, 1442, 1430, 1417, 1404, 1392, 1379, 1366, 13 ...

# %%
for key, val in results.items():
    print(f'{key}: {type(val)}')
# Out:
# timestamp: <class 'str'>
# driver_version: <class 'str'>
# count: <class 'int'>
# gpu: <class 'list'>

# %%
results['gpu'][0]
# Out:
# {'id': '00000000:01:00.0',
#  'product_name': 'NVIDIA GeForce GTX 1080 Ti',
#  'product_brand': 'GeForce',
#  'display_mode': 'Disabled',
#  'display_active': 'Disabled',
#  'persistence_mode': 'Disabled',
#  'mig_mode': {'current_mm': 'Disabled', 'pending_mm': 'Disabled'},
#  'accounting_mode': 'Disabled',
#  'accounting_mode_buffer_size': '4000',
#  'driver_model': {'current_dm': 'N/A', 'pending_dm': 'N/A'},
#  'serial': 'N/A',
#  'uuid': 'GPU-a2512dc7-f7c2-ebb4-9001-2588ed530c8f',
#  'minor_number': '0',
#  'vbios_version': '86.02.39.00.A2',
#  'multigpu_board': 'No',
#  'board_id': '0x100',
#  'inforom_version': {'img_version': 'G001.0000.01.04',
#   'oem_object': '1.1',
#   'ecc_object': 'N/A',
#   'pwr_object': 'N/A'},
#  'gpu_operation_mode': {'current_gom': 'N/A', 'pending_gom': 'N/A'},
#  'pci': {'pci_bus': '01',
#   'pci_device': '00',
#   'pci_domain': '0000',
#   'pci_device_id': '1B0610DE',
#   'pci_bus_id': '00000000:01:00.0',
#   'pci_sub_system_id': '1211196E',
#   'pci_gpu_link_info': {'pcie_gen': {'max_link_gen': '3',
#     'current_link_gen': '1'},
#    'link_widths': {'max_link_width': '16x', 'current_link_width': '16x'}},
#   'pci_bridge_chip': {'bridge_chip_type': 'N/A', 'bridge_chip_fw': 'N/A'},
#   'replay_counter': '0',
#   'tx_util': 0,
#   'tx_util_unit': 'KB/s',
#   'rx_util': 0,
#   'rx_util_unit': 'KB/s'},
#  'fan_speed': 41,
#  'fan_speed_unit': '%',
#  'performance_state': 'P8',
#  'clocks_throttle': {'clocks_throttle_reason_gpu_idle': 'Active',
#   'clocks_throttle_reason_applications_clocks_setting': 'Not Active',
#   'clocks_throttle_reason_sw_power_cap': 'Not Active',
#   'clocks_throttle_reason_hw_slowdown': 'Not Active',
#   'clocks_throttle_reason_none': 'N/A'},
#  'fb_memory_usage': {'total': 11175.375,
#   'used': 514.875,
#   'free': 10660.5,
#   'unit': 'MiB'},
#  'bar1_memory_usage': {'total': 256.0,
#   'used': 6.3125,
#   'free': 249.6875,
#   'unit': 'MiB'},
#  'compute_mode': 'Default',
#  'utilization': {'gpu_util': 0,
#   'memory_util': 0,
#   'encoder_util': 0,
#   'decoder_util': 0,
#   'unit': '%'},
#  'ecc_mode': {'current_ecc': 'N/A', 'pending_ecc': 'N/A'},
#  'ecc_errors': {'volatile': {'single_bit': {'device_memory': 'N/A',
#     'dram': 'N/A',
#     'register_file': 'N/A',
#     'l1_cache': 'N/A',
#     'l2_cache': 'N/A',
#     'texture_memory': 'N/A',
#     'cbu': 'N/A',
#     'sram': 'N/A',
#     'total': 'N/A'},
#    'double_bit': {'device_memory': 'N/A',
#     'dram': 'N/A',
#     'register_file': 'N/A',
#     'l1_cache': 'N/A',
#     'l2_cache': 'N/A',
#     'texture_memory': 'N/A',
#     'cbu': 'N/A',
#     'sram': 'N/A',
#     'total': 'N/A'}},
#   'aggregate': {'single_bit': {'device_memory': 'N/A',
#     'dram': 'N/A',
#     'register_file': 'N/A',
#     'l1_cache': 'N/A',
#     'l2_cache': 'N/A',
#     'texture_memory': 'N/A',
#     'cbu': 'N/A',
#     'sram': 'N/A',
#     'total': 'N/A'},
#    'double_bit': {'device_memory': 'N/A',
#     'dram': 'N/A',
#     'register_file': 'N/A',
#     'l1_cache': 'N/A',
#     'l2_cache': 'N/A',
#     'texture_memory': 'N/A',
#     'cbu': 'N/A',
#     'sram': 'N/A',
#     'total': 'N/A'}}},
#  'retired_pages': {'multiple_single_bit_retirement': None,
#   'double_bit_retirement': None,
#   'pending_retirement': 'N/A'},
#  'temperature': {'gpu_temp': 26,
#   'gpu_temp_max_threshold': 96,
#   'gpu_temp_slow_threshold': 93,
#   'unit': 'C'},
#  'power_readings': {'power_management': 'Supported',
#   'power_draw': 9.473,
#   'power_limit': 250.0,
#   'default_power_limit': 250.0,
#   'enforced_power_limit': 250.0,
#   'min_power_limit': 125.0,
#   'max_power_limit': 300.0,
#   'power_state': 'P8',
#   'unit': 'W'},
#  'clocks': {'graphics_clock': 139,
#   'sm_clock': 139,
#   'mem_clock': 405,
#   'unit': 'MHz'},
#  'applications_clocks': {'graphics_clock': 'N/A',
#   'mem_clock': 'N/A',
#   'unit': 'MHz'},
#  'default_applications_clocks': {'graphics_clock': 'N/A',
#   'mem_clock': 'N/A',
#   'unit': 'MHz'},
#  'max_clocks': {'graphics_clock': 1961,
#   'sm_clock': 1961,
#   'mem_clock': 5505,
#   'unit': 'MHz'},
#  'clock_policy': {'auto_boost': 'N/A', 'auto_boost_default': 'N/A'},
#  'supported_clocks': [{'current': 5505,
#    'unit': 'MHz',
#    'supported_graphics_clock': [1961,
#     1949,
#     1936,
#     1923,
#     1911,
#     1898,
#     1885,
#     1873,
#     1860,
#     1847,
#     1835,
#     1822,
#     1809,
#     1797,
#     1784,
#     1771,
#     1759,
#     1746,
#     1733,
#     1721,
#     1708,
#     1695,
#     1683,
#     1670,
#     1657,
#     1645,
#     1632,
#     1620,
#     1607,
#     1594,
#     1582,
#     1569,
#     1556,
#     1544,
#     1531,
#     1518,
#     1506,
#     1493,
#     1480,
#     1468,
#     1455,
#     1442,
#     1430,
#     1417,
#     1404,
#     1392,
#     1379,
#     1366,
#     1354,
#     1341,
#     1328,
#     1316,
#     1303,
#     1290,
#     1278,
#     1265,
#     1252,
#     1240,
#     1227,
#     1215,
#     1202,
#     1189,
#     1177,
#     1164,
#     1151,
#     1139,
#     1126,
#     1113,
#     1101,
#     1088,
#     1075,
#     1063,
#     1050,
#     1037,
#     1025,
#     1012,
#     999,
#     987,
#     974,
#     961,
#     949,
#     936,
#     923,
#     911,
#     898,
#     885,
#     873,
#     860,
#     847,
#     835,
#     822,
#     810,
#     797,
#     784,
#     772,
#     759,
#     746,
#     734,
#     721,
#     708,
#     696,
#     683,
#     670,
#     658,
#     645,
#     632,
#     620,
#     607,
#     594,
#     582,
#     569,
#     556,
#     544,
#     531,
#     518,
#     506,
#     493,
#     480,
#     468,
#     455,
#     442,
#     430,
#     417,
#     405,
#     392,
#     379,
#     367,
#     354,
#     341,
#     329,
#     316,
#     303,
#     291,
#     278,
#     265,
#     253,
#     240,
#     227,
#     215,
#     202]},
#   {'current': 5005,
#    'unit': 'MHz',
#    'supported_graphics_clock': [1961,
#     1949,
#     1936,
#     1923,
#     1911,
#     1898,
#     1885,
#     1873,
#     1860,
#     1847,
#     1835,
#     1822,
#     1809,
#     1797,
#     1784,
#     1771,
#     1759,
#     1746,
#     1733,
#     1721,
#     1708,
#     1695,
#     1683,
#     1670,
#     1657,
#     1645,
#     1632,
#     1620,
#     1607,
#     1594,
#     1582,
#     1569,
#     1556,
#     1544,
#     1531,
#     1518,
#     1506,
#     1493,
#     1480,
#     1468,
#     1455,
#     1442,
#     1430,
#     1417,
#     1404,
#     1392,
#     1379,
#     1366,
#     1354,
#     1341,
#     1328,
#     1316,
#     1303,
#     1290,
#     1278,
#     1265,
#     1252,
#     1240,
#     1227,
#     1215,
#     1202,
#     1189,
#     1177,
#     1164,
#     1151,
#     1139,
#     1126,
#     1113,
#     1101,
#     1088,
#     1075,
#     1063,
#     1050,
#     1037,
#     1025,
#     1012,
#     999,
#     987,
#     974,
#     961,
#     949,
#     936,
#     923,
#     911,
#     898,
#     885,
#     873,
#     860,
#     847,
#     835,
#     822,
#     810,
#     797,
#     784,
#     772,
#     759,
#     746,
#     734,
#     721,
#     708,
#     696,
#     683,
#     670,
#     658,
#     645,
#     632,
#     620,
#     607,
#     594,
#     582,
#     569,
#     556,
#     544,
#     531,
#     518,
#     506,
#     493,
#     480,
#     468,
#     455,
#     442,
#     430,
#     417,
#     405,
#     392,
#     379,
#     367,
#     354,
#     341,
#     329,
#     316,
#     303,
#     291,
#     278,
#     265,
#     253,
#     240,
#     227,
#     215,
#     202]},
#   {'current': 810,
#    'unit': 'MHz',
#    'supported_graphics_clock': [1911,
#     1898,
#     1885,
#     1873,
#     1860,
#     1847,
#     1835,
#     1822,
#     1809,
#     1797,
#     1784,
#     1771,
#     1759,
#     1746,
#     1733,
#     1721,
#     1708,
#     1695,
#     1683,
#     1670,
#     1657,
#     1645,
#     1632,
#     1620,
#     1607,
#     1594,
#     1582,
#     1569,
#     1556,
#     1544,
#     1531,
#     1518,
#     1506,
#     1493,
#     1480,
#     1468,
#     1455,
#     1442,
#     1430,
#     1417,
#     1404,
#     1392,
#     1379,
#     1366,
#     1354,
#     1341,
#     1328,
#     1316,
#     1303,
#     1290,
#     1278,
#     1265,
#     1252,
#     1240,
#     1227,
#     1215,
#     1202,
#     1189,
#     1177,
#     1164,
#     1151,
#     1139,
#     1126,
#     1113,
#     1101,
#     1088,
#     1075,
#     1063,
#     1050,
#     1037,
#     1025,
#     1012,
#     999,
#     987,
#     974,
#     961,
#     949,
#     936,
#     923,
#     911,
#     898,
#     885,
#     873,
#     860,
#     847,
#     835,
#     822,
#     810,
#     797,
#     784,
#     772,
#     759,
#     746,
#     734,
#     721,
#     708,
#     696,
#     683,
#     670,
#     658,
#     645,
#     632,
#     620,
#     607,
#     594,
#     582,
#     569,
#     556,
#     544,
#     531,
#     518,
#     506,
#     493,
#     480,
#     468,
#     455,
#     442,
#     430,
#     417,
#     405,
#     392,
#     379,
#     367,
#     354,
#     341,
#     329,
#     316,
#     303,
#     291,
#     278,
#     265,
#     253,
#     240,
#     227,
#     215,
#     202,
#     189,
#     177,
#     164,
#     151,
#     139]},
#   {'current': 405,
#    'unit': 'MHz',
#    'supported_graphics_clock': [607,
#     594,
#     582,
#     569,
#     556,
#     544,
#     531,
#     518,
#     506,
#     493,
#     480,
#     468,
#     455,
#     442,
#     430,
#     417,
#     405,
#     392,
#     379,
#     367,
#     354,
#     341,
#     329,
#     316,
#     303,
#     291,
#     278,
#     265,
#     253,
#     240,
#     227,
#     215,
#     202,
#     189,
#     177,
#     164,
#     151,
#     139]}],
#  'processes': 'Function Not Found',
#  'accounted_processes': None}

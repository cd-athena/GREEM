# %%
import pandas as pd

# %%
data_path: str = 'quarter_second'

# %%
comparison_df = pd.read_csv(f'{data_path}/data.csv')
comparison_df
# Out:
#        Reading #   Reading
# 0              0  0.686903
# 1              1  0.686903
# 2              2  0.686903
# 3              3  0.683599
# 4              4  0.683599
# ...          ...       ...
# 46574      46574  0.751316
# 46575      46575  0.751316
# 46576      46576  0.804847
# 46577      46577  0.804847
# 46578      46578  0.804847
#
# [46579 rows x 2 columns]

# %%
comparison_df['ampere'] = comparison_df['Reading']
volt = 20
comparison_df['watt'] = comparison_df['ampere'] * volt
comparison_df['watt_norm'] = comparison_df['watt'] / comparison_df['watt'].max()

# %%
# comparison_df['watt_norm'][comparison_df['watt_norm'] > 0.6][6500:].plot.line()
# comparison_df['watt_norm'][comparison_df['watt_norm'] > 0.4].dropna().plot.line()
comparison_df['watt_norm'][comparison_df['watt_norm'] > 0.4].rolling(500).mean().dropna().plot.line()
# comparison_df['watt_norm'][comparison_df['watt_norm'] > 0.65][5000:]
# Out:
# <Axes: >

# %%
greem_df = pd.read_csv(f'{data_path}/emissions.csv')
greem_df.head()
# Out:
#              timestamp    project_name                                run_id  \
# 0  2024-02-29T15:52:58  encoding_stage  f3a389c0-3193-4e6f-a206-3de9ec235d3f
# 1  2024-02-29T15:53:15  encoding_stage  3a24f08f-d4a9-4a57-bb70-4010d8f3a4c6
# 2  2024-02-29T15:53:33  encoding_stage  b3e36761-99b8-4833-bac3-cdbcfea2aae8
# 3  2024-02-29T15:53:52  encoding_stage  8f52562e-7f13-4e36-93a1-6195eb62496a
# 4  2024-02-29T15:54:10  encoding_stage  93e8a5cf-7ef9-440c-9576-b7ccfc03caf8
#
#     duration  emissions  emissions_rate   cpu_power  gpu_power  ram_power  \
# 0  16.544354   0.000023        0.000001  126.605944        0.0   5.747884
# 1  16.536699   0.000022        0.000001   17.699724        0.0   5.747884
# 2  17.040512   0.000022        0.000001   31.171915        0.0   5.747884
# 3  17.496135   0.000022        0.000001   32.648678        0.0   5.747884
# 4  17.080777   0.000021        0.000001   22.215540        0.0   5.747884
#
#    cpu_energy  ...  codecarbon_version  cpu_count  \
# ...

# %%
greem_df['energy_consumed_norm'] = greem_df['energy_consumed'] / greem_df['energy_consumed'].max()

# %%
greem_df['energy_consumed_norm'].plot.line()
# Out:
# <Axes: >

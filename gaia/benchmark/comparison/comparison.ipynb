# %%
import pandas as pd

# %%
data_path: str = 'quarter_second'

# %%
comparison_df = pd.read_csv(f'{data_path}/data.csv')
comparison_df
# Out:
#       Reading #  Reading
# 0             0  3.26415
# 1             1  3.26415
# 2             2  2.74938
# 3             3  2.74938
# 4             4  2.74938
# ...         ...      ...
# 3691       3691  3.06304
# 3692       3692  3.09235
# 3693       3693  3.09235
# 3694       3694  3.09235
# 3695       3695  3.07000
#
# [3696 rows x 2 columns]

# %%
comparison_df['ampere'] = comparison_df['Reading']
volt = 20
comparison_df['watt'] = comparison_df['ampere'] * volt
comparison_df['watt_norm'] = comparison_df['watt'] / comparison_df['watt'].max()

# %%
comparison_df['watt_norm'][comparison_df['watt_norm'] > 0.65].plot.line()
# Out:
# <Axes: >

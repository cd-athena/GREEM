# %%
from gaia.utils.monitoring import BaseMonitoring, RegularMonitoring, PeriodicMonitoring
from codecarbon import EmissionsTracker
import os
import pandas as pd

# %%
# rm = RegularMonitoring(measure_power_secs=10)
tracker = EmissionsTracker(measure_power_secs=1)
# pm = PeriodicMonitoring(measure_power_secs=0.5)
# Out:
# [codecarbon INFO @ 15:33:55] [setup] RAM Tracking...
# [codecarbon INFO @ 15:33:55] [setup] GPU Tracking...
# [codecarbon INFO @ 15:33:55] No GPU found.
# [codecarbon INFO @ 15:33:55] [setup] CPU Tracking...
# [codecarbon WARNING @ 15:33:55] No CPU tracking mode found. Falling back on CPU constant mode.
# [codecarbon INFO @ 15:33:55] CPU Model on constant consumption mode: Apple M1 Max
# [codecarbon INFO @ 15:33:55] >>> Tracker's metadata:
# [codecarbon INFO @ 15:33:55]   Platform system: macOS-14.2.1-arm64-arm-64bit
# [codecarbon INFO @ 15:33:55]   Python version: 3.10.13
# [codecarbon INFO @ 15:33:55]   CodeCarbon version: 2.2.2
# [codecarbon INFO @ 15:33:55]   Available RAM : 32.000 GB
# [codecarbon INFO @ 15:33:55]   CPU count: 10
# [codecarbon INFO @ 15:33:55]   CPU model: Apple M1 Max
# [codecarbon INFO @ 15:33:55]   GPU count: None
# [codecarbon INFO @ 15:33:55]   GPU model: None

# %%
# for i in range(12):
#     rm.start_monitoring('sleep 2')

# # rm.tracker.stop()
# rm.tracker.stop()

for _ in range(5):
    tracker.start()
    os.system('ffmpeg -y -re -i Beauty_s000.265 -b:v:0 1000k -b:v:0 1000k -minrate 1000k -maxrate 1000k -bufsize 3000k -c:v:0 libx264 -filter:v:0 "scale=200:100 ,fps=10" -preset medium -keyint_min 10 -g 10 test.mp4')
    tracker.stop()
# Out:
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.1.0.2.5)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.1.1_3 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# [hevc @ 0x14d72fa60] Stream #0: not enough frames to estimate rate; consider increasing probesize
# Input #0, hevc, from 'Beauty_s000.265':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: hevc (Main), yuv420p(tv), 3840x2160, 25 fps, 23.98 tbr, 1200k tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (hevc (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x12d605ad0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12d605ad0] profile High, level 2.1, 4:2:0, 8-bit
# [libx264 @ 0x12d605ad0] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=10 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=cbr mbtree=1 bitrate=1000 ratetol=1.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 vbv_maxrate=1000 vbv_bufsize=3000 nal_hrd=none filler=0 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'test.mp4':
#   Metadata:
#     encoder         : Lavf60.16.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 200x100, q=2-31, 1000 kb/s, 10 fps, 10240 tbn
#     Metadata:
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 1000000/0/1000000 buffer size: 3000000 vbv_delay: N/A
# [out#0/mp4 @ 0x12d6049d0] video:566kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.248851%
# frame=   50 fps=5.6 q=-1.0 Lsize=     568kB time=00:00:04.70 bitrate= 989.5kbits/s speed=0.524x
# [libx264 @ 0x12d605ad0] frame I:5     Avg QP: 0.82  size: 13881
# [libx264 @ 0x12d605ad0] frame P:15    Avg QP: 1.69  size: 12317
# [libx264 @ 0x12d605ad0] frame B:30    Avg QP: 2.35  size: 10831
# [libx264 @ 0x12d605ad0] consecutive B-frames: 18.0%  4.0%  6.0% 72.0%
# [libx264 @ 0x12d605ad0] mb I  I16..4: 13.0% 22.6% 64.4%
# [libx264 @ 0x12d605ad0] mb P  I16..4:  7.2% 17.4% 34.7%  P16..4: 10.3% 17.2% 13.2%  0.0%  0.0%    skip: 0.0%
# [libx264 @ 0x12d605ad0] mb B  I16..4:  3.4% 17.3% 23.2%  B16..8: 12.7% 14.6% 19.4%  direct: 9.6%  skip: 0.0%  L0:34.3% L1:25.4% BI:40.3%
# [libx264 @ 0x12d605ad0] 8x8 transform intra:33.0% inter:23.3%
# [libx264 @ 0x12d605ad0] coded y,uvDC,uvAC intra: 90.2% 100.0% 100.0% inter: 99.1% 100.0% 99.8%
# [libx264 @ 0x12d605ad0] i16 v,h,dc,p: 22%  2% 63% 13%
# [libx264 @ 0x12d605ad0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18%  4% 59%  1%  4%  8%  2%  2%  2%
# [libx264 @ 0x12d605ad0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 18% 15%  4% 11%  8% 10%  6%  6%
# [libx264 @ 0x12d605ad0] i8c dc,h,v,p: 66% 10% 14% 10%
# [libx264 @ 0x12d605ad0] Weighted P-Frames: Y:6.7% UV:0.0%
# [libx264 @ 0x12d605ad0] ref P L0: 63.2% 18.4% 12.0%  5.8%  0.5%
# [libx264 @ 0x12d605ad0] ref B L0: 86.3% 11.5%  2.1%
# [libx264 @ 0x12d605ad0] ref B L1: 95.4%  4.6%
# [libx264 @ 0x12d605ad0] kb/s:926.57
# [codecarbon INFO @ 15:34:08] Energy consumed for RAM : 0.000032 kWh. RAM Power : 12.0 W
# [codecarbon INFO @ 15:34:08] Energy consumed for all CPUs : 0.000013 kWh. Total CPU Power : 5.0 W
# [codecarbon INFO @ 15:34:08] 0.000046 kWh of electricity used since the beginning.
# [codecarbon WARNING @ 15:34:08] Already started tracking
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.1.0.2.5)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.1.1_3 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# [hevc @ 0x153004480] Stream #0: not enough frames to estimate rate; consider increasing probesize
# Input #0, hevc, from 'Beauty_s000.265':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: hevc (Main), yuv420p(tv), 3840x2160, 25 fps, 23.98 tbr, 1200k tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (hevc (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x151719b40] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x151719b40] profile High, level 2.1, 4:2:0, 8-bit
# [libx264 @ 0x151719b40] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=10 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=cbr mbtree=1 bitrate=1000 ratetol=1.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 vbv_maxrate=1000 vbv_bufsize=3000 nal_hrd=none filler=0 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'test.mp4':
#   Metadata:
#     encoder         : Lavf60.16.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 200x100, q=2-31, 1000 kb/s, 10 fps, 10240 tbn
#     Metadata:
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 1000000/0/1000000 buffer size: 3000000 vbv_delay: N/A
# [out#0/mp4 @ 0x151718280] video:566kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.248851%
# frame=   50 fps=5.6 q=-1.0 Lsize=     568kB time=00:00:04.70 bitrate= 989.5kbits/s speed=0.53x
# [libx264 @ 0x151719b40] frame I:5     Avg QP: 0.82  size: 13881
# [libx264 @ 0x151719b40] frame P:15    Avg QP: 1.69  size: 12317
# [libx264 @ 0x151719b40] frame B:30    Avg QP: 2.35  size: 10831
# [libx264 @ 0x151719b40] consecutive B-frames: 18.0%  4.0%  6.0% 72.0%
# [libx264 @ 0x151719b40] mb I  I16..4: 13.0% 22.6% 64.4%
# [libx264 @ 0x151719b40] mb P  I16..4:  7.2% 17.4% 34.7%  P16..4: 10.3% 17.2% 13.2%  0.0%  0.0%    skip: 0.0%
# [libx264 @ 0x151719b40] mb B  I16..4:  3.4% 17.3% 23.2%  B16..8: 12.7% 14.6% 19.4%  direct: 9.6%  skip: 0.0%  L0:34.3% L1:25.4% BI:40.3%
# [libx264 @ 0x151719b40] 8x8 transform intra:33.0% inter:23.3%
# [libx264 @ 0x151719b40] coded y,uvDC,uvAC intra: 90.2% 100.0% 100.0% inter: 99.1% 100.0% 99.8%
# [libx264 @ 0x151719b40] i16 v,h,dc,p: 22%  2% 63% 13%
# [libx264 @ 0x151719b40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18%  4% 59%  1%  4%  8%  2%  2%  2%
# [libx264 @ 0x151719b40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 18% 15%  4% 11%  8% 10%  6%  6%
# [libx264 @ 0x151719b40] i8c dc,h,v,p: 66% 10% 14% 10%
# [libx264 @ 0x151719b40] Weighted P-Frames: Y:6.7% UV:0.0%
# [libx264 @ 0x151719b40] ref P L0: 63.2% 18.4% 12.0%  5.8%  0.5%
# [libx264 @ 0x151719b40] ref B L0: 86.3% 11.5%  2.1%
# [libx264 @ 0x151719b40] ref B L1: 95.4%  4.6%
# [libx264 @ 0x151719b40] kb/s:926.57
# [codecarbon WARNING @ 15:34:17] Tracker already stopped !
# [codecarbon WARNING @ 15:34:17] Already started tracking
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.1.0.2.5)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.1.1_3 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# [hevc @ 0x138e3b200] Stream #0: not enough frames to estimate rate; consider increasing probesize
# Input #0, hevc, from 'Beauty_s000.265':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: hevc (Main), yuv420p(tv), 3840x2160, 25 fps, 23.98 tbr, 1200k tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (hevc (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x138f09220] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x138f09220] profile High, level 2.1, 4:2:0, 8-bit
# [libx264 @ 0x138f09220] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=10 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=cbr mbtree=1 bitrate=1000 ratetol=1.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 vbv_maxrate=1000 vbv_bufsize=3000 nal_hrd=none filler=0 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'test.mp4':
#   Metadata:
#     encoder         : Lavf60.16.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 200x100, q=2-31, 1000 kb/s, 10 fps, 10240 tbn
#     Metadata:
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 1000000/0/1000000 buffer size: 3000000 vbv_delay: N/A
# [out#0/mp4 @ 0x138f08170] video:566kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.248851%
# frame=   50 fps=5.7 q=-1.0 Lsize=     568kB time=00:00:04.70 bitrate= 989.5kbits/s speed=0.534x
# [libx264 @ 0x138f09220] frame I:5     Avg QP: 0.82  size: 13881
# [libx264 @ 0x138f09220] frame P:15    Avg QP: 1.69  size: 12317
# [libx264 @ 0x138f09220] frame B:30    Avg QP: 2.35  size: 10831
# [libx264 @ 0x138f09220] consecutive B-frames: 18.0%  4.0%  6.0% 72.0%
# [libx264 @ 0x138f09220] mb I  I16..4: 13.0% 22.6% 64.4%
# [libx264 @ 0x138f09220] mb P  I16..4:  7.2% 17.4% 34.7%  P16..4: 10.3% 17.2% 13.2%  0.0%  0.0%    skip: 0.0%
# [libx264 @ 0x138f09220] mb B  I16..4:  3.4% 17.3% 23.2%  B16..8: 12.7% 14.6% 19.4%  direct: 9.6%  skip: 0.0%  L0:34.3% L1:25.4% BI:40.3%
# [libx264 @ 0x138f09220] 8x8 transform intra:33.0% inter:23.3%
# [libx264 @ 0x138f09220] coded y,uvDC,uvAC intra: 90.2% 100.0% 100.0% inter: 99.1% 100.0% 99.8%
# [libx264 @ 0x138f09220] i16 v,h,dc,p: 22%  2% 63% 13%
# [libx264 @ 0x138f09220] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18%  4% 59%  1%  4%  8%  2%  2%  2%
# [libx264 @ 0x138f09220] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 18% 15%  4% 11%  8% 10%  6%  6%
# [libx264 @ 0x138f09220] i8c dc,h,v,p: 66% 10% 14% 10%
# [libx264 @ 0x138f09220] Weighted P-Frames: Y:6.7% UV:0.0%
# [libx264 @ 0x138f09220] ref P L0: 63.2% 18.4% 12.0%  5.8%  0.5%
# [libx264 @ 0x138f09220] ref B L0: 86.3% 11.5%  2.1%
# [libx264 @ 0x138f09220] ref B L1: 95.4%  4.6%
# [libx264 @ 0x138f09220] kb/s:926.57
# [codecarbon WARNING @ 15:34:27] Tracker already stopped !
# [codecarbon WARNING @ 15:34:27] Already started tracking
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.1.0.2.5)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.1.1_3 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# [hevc @ 0x129717e10] Stream #0: not enough frames to estimate rate; consider increasing probesize
# Input #0, hevc, from 'Beauty_s000.265':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: hevc (Main), yuv420p(tv), 3840x2160, 25 fps, 23.98 tbr, 1200k tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (hevc (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x12962c5e0] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x12962c5e0] profile High, level 2.1, 4:2:0, 8-bit
# [libx264 @ 0x12962c5e0] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=10 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=cbr mbtree=1 bitrate=1000 ratetol=1.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 vbv_maxrate=1000 vbv_bufsize=3000 nal_hrd=none filler=0 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'test.mp4':
#   Metadata:
#     encoder         : Lavf60.16.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 200x100, q=2-31, 1000 kb/s, 10 fps, 10240 tbn
#     Metadata:
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 1000000/0/1000000 buffer size: 3000000 vbv_delay: N/A
# [out#0/mp4 @ 0x12962b1a0] video:566kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.248851%
# frame=   50 fps=5.7 q=-1.0 Lsize=     568kB time=00:00:04.70 bitrate= 989.5kbits/s speed=0.533x
# [libx264 @ 0x12962c5e0] frame I:5     Avg QP: 0.82  size: 13881
# [libx264 @ 0x12962c5e0] frame P:15    Avg QP: 1.69  size: 12317
# [libx264 @ 0x12962c5e0] frame B:30    Avg QP: 2.35  size: 10831
# [libx264 @ 0x12962c5e0] consecutive B-frames: 18.0%  4.0%  6.0% 72.0%
# [libx264 @ 0x12962c5e0] mb I  I16..4: 13.0% 22.6% 64.4%
# [libx264 @ 0x12962c5e0] mb P  I16..4:  7.2% 17.4% 34.7%  P16..4: 10.3% 17.2% 13.2%  0.0%  0.0%    skip: 0.0%
# [libx264 @ 0x12962c5e0] mb B  I16..4:  3.4% 17.3% 23.2%  B16..8: 12.7% 14.6% 19.4%  direct: 9.6%  skip: 0.0%  L0:34.3% L1:25.4% BI:40.3%
# [libx264 @ 0x12962c5e0] 8x8 transform intra:33.0% inter:23.3%
# [libx264 @ 0x12962c5e0] coded y,uvDC,uvAC intra: 90.2% 100.0% 100.0% inter: 99.1% 100.0% 99.8%
# [libx264 @ 0x12962c5e0] i16 v,h,dc,p: 22%  2% 63% 13%
# [libx264 @ 0x12962c5e0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18%  4% 59%  1%  4%  8%  2%  2%  2%
# [libx264 @ 0x12962c5e0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 18% 15%  4% 11%  8% 10%  6%  6%
# [libx264 @ 0x12962c5e0] i8c dc,h,v,p: 66% 10% 14% 10%
# [libx264 @ 0x12962c5e0] Weighted P-Frames: Y:6.7% UV:0.0%
# [libx264 @ 0x12962c5e0] ref P L0: 63.2% 18.4% 12.0%  5.8%  0.5%
# [libx264 @ 0x12962c5e0] ref B L0: 86.3% 11.5%  2.1%
# [libx264 @ 0x12962c5e0] ref B L1: 95.4%  4.6%
# [libx264 @ 0x12962c5e0] kb/s:926.57
# [codecarbon WARNING @ 15:34:36] Tracker already stopped !
# [codecarbon WARNING @ 15:34:36] Already started tracking
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.1.0.2.5)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.1.1_3 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# [hevc @ 0x144114700] Stream #0: not enough frames to estimate rate; consider increasing probesize
# Input #0, hevc, from 'Beauty_s000.265':
#   Duration: N/A, bitrate: N/A
#   Stream #0:0: Video: hevc (Main), yuv420p(tv), 3840x2160, 25 fps, 23.98 tbr, 1200k tbn
# Stream mapping:
#   Stream #0:0 -> #0:0 (hevc (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x14411f250] using cpu capabilities: ARMv8 NEON
# [libx264 @ 0x14411f250] profile High, level 2.1, 4:2:0, 8-bit
# [libx264 @ 0x14411f250] 264 - core 164 r3108 31e19f9 - H.264/MPEG-4 AVC codec - Copyleft 2003-2023 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=10 keyint_min=6 scenecut=40 intra_refresh=0 rc_lookahead=30 rc=cbr mbtree=1 bitrate=1000 ratetol=1.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 vbv_maxrate=1000 vbv_bufsize=3000 nal_hrd=none filler=0 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'test.mp4':
#   Metadata:
#     encoder         : Lavf60.16.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 200x100, q=2-31, 1000 kb/s, 10 fps, 10240 tbn
#     Metadata:
#       encoder         : Lavc60.31.102 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 1000000/0/1000000 buffer size: 3000000 vbv_delay: N/A
# [out#0/mp4 @ 0x1441137b0] video:566kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.248851%
# frame=   50 fps=5.6 q=-1.0 Lsize=     568kB time=00:00:04.70 bitrate= 989.5kbits/s speed=0.53x
# [libx264 @ 0x14411f250] frame I:5     Avg QP: 0.82  size: 13881
# [libx264 @ 0x14411f250] frame P:15    Avg QP: 1.69  size: 12317
# [libx264 @ 0x14411f250] frame B:30    Avg QP: 2.35  size: 10831
# [libx264 @ 0x14411f250] consecutive B-frames: 18.0%  4.0%  6.0% 72.0%
# [libx264 @ 0x14411f250] mb I  I16..4: 13.0% 22.6% 64.4%
# [libx264 @ 0x14411f250] mb P  I16..4:  7.2% 17.4% 34.7%  P16..4: 10.3% 17.2% 13.2%  0.0%  0.0%    skip: 0.0%
# [libx264 @ 0x14411f250] mb B  I16..4:  3.4% 17.3% 23.2%  B16..8: 12.7% 14.6% 19.4%  direct: 9.6%  skip: 0.0%  L0:34.3% L1:25.4% BI:40.3%
# [libx264 @ 0x14411f250] 8x8 transform intra:33.0% inter:23.3%
# [libx264 @ 0x14411f250] coded y,uvDC,uvAC intra: 90.2% 100.0% 100.0% inter: 99.1% 100.0% 99.8%
# [libx264 @ 0x14411f250] i16 v,h,dc,p: 22%  2% 63% 13%
# [libx264 @ 0x14411f250] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18%  4% 59%  1%  4%  8%  2%  2%  2%
# [libx264 @ 0x14411f250] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 18% 15%  4% 11%  8% 10%  6%  6%
# [libx264 @ 0x14411f250] i8c dc,h,v,p: 66% 10% 14% 10%
# [libx264 @ 0x14411f250] Weighted P-Frames: Y:6.7% UV:0.0%
# [libx264 @ 0x14411f250] ref P L0: 63.2% 18.4% 12.0%  5.8%  0.5%
# [libx264 @ 0x14411f250] ref B L0: 86.3% 11.5%  2.1%
# [libx264 @ 0x14411f250] ref B L1: 95.4%  4.6%
# [libx264 @ 0x14411f250] kb/s:926.57
# [codecarbon WARNING @ 15:34:46] Tracker already stopped !

# %%
# rm.collected_data

# %%
# for i in rm.collected_data:
#     print(type(i))
